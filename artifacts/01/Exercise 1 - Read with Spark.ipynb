# %%
# %%pyspark
# data_path = spark.read.load(
#     'abfss://wwi@<primary_storage>.dfs.core.windows.net/factsale-csv/2012/Q1/*/*',
#     format='csv',
#     sep="|",
#     header=True)
#
# display(data_path.limit(100))
